# %%
import pandas as pd

# %%
df = pd.read_csv('pokemon.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# ## Index

# %%
# want to re-arrange all the columns
cols=list(df.columns)
df = df[cols[:5]+[cols[-1]]+cols[5:10]]
df
# Out:
#        #                   Name   Type 1  Type 2  Total  Legendary  HP  \
# 0      1              Bulbasaur    Grass  Poison    318      False  45
# 1      2                Ivysaur    Grass  Poison    405      False  60
# 2      3               Venusaur    Grass  Poison    525      False  80
# 3      3  VenusaurMega Venusaur    Grass  Poison    625      False  80
# 4      4             Charmander     Fire     NaN    309      False  39
# ..   ...                    ...      ...     ...    ...        ...  ..
# 795  719                Diancie     Rock   Fairy    600       True  50
# 796  719    DiancieMega Diancie     Rock   Fairy    700       True  50
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600       True  80
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680       True  80
# 799  721              Volcanion     Fire   Water    600       True  80
#
#      Attack  Defense  Sp. Atk  Sp. Def
# 0        49       49       65       65
# ...

# %% [markdown]
# ## save

# %%
# modified DataFrame saved in folder
df.to_csv("midified_pokemon.csv")

# %%
df.to_excel("midified_pokemon.xlsx")

# %%
df.to_csv("midified_pokemon.txt",sep='\t')

# %%
df.loc[df['Type 1'] == 'Grass']
# Out:
#        #                   Name Type 1    Type 2  Total  Legendary  HP  \
# 0      1              Bulbasaur  Grass    Poison    318      False  50
# 1      2                Ivysaur  Grass    Poison    405      False  50
# 2      3               Venusaur  Grass    Poison    525      False   1
# 3      3  VenusaurMega Venusaur  Grass    Poison    625      False   1
# 48    43                 Oddish  Grass    Poison    320      False  50
# ..   ...                    ...    ...       ...    ...        ...  ..
# 718  650                Chespin  Grass       NaN    313      False  50
# 719  651              Quilladin  Grass       NaN    405      False  50
# 720  652             Chesnaught  Grass  Fighting    530      False   1
# 740  672                 Skiddo  Grass       NaN    350      False  50
# 741  673                 Gogoat  Grass       NaN    531      False   1
#
#      Attack  Defense  Sp. Atk  Sp. Def
# 0        49       49       65       65
# ...

# %% [markdown]
# ## Filter

# %%
df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP']>70)]
# Out:
#        #                   Name Type 1  Type 2  Total  Legendary   HP  Attack  \
# 2      3               Venusaur  Grass  Poison    525      False   80      82
# 3      3  VenusaurMega Venusaur  Grass  Poison    625      False   80     100
# 50    45              Vileplume  Grass  Poison    490      False   75      80
# 77    71             Victreebel  Grass  Poison    490      False   80     105
# 652  591              Amoonguss  Grass  Poison    464      False  114      85
#
#      Defense  Sp. Atk  Sp. Def
# 2         83      100      100
# 3        123      122      120
# 50        85      110       90
# 77        65      100       70
# 652       70       85       80

# %%
new_df = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP']>70)]
new_df
# Out:
#        #                   Name Type 1  Type 2  Total  Legendary   HP  Attack  \
# 2      3               Venusaur  Grass  Poison    525      False   80      82
# 3      3  VenusaurMega Venusaur  Grass  Poison    625      False   80     100
# 50    45              Vileplume  Grass  Poison    490      False   75      80
# 77    71             Victreebel  Grass  Poison    490      False   80     105
# 652  591              Amoonguss  Grass  Poison    464      False  114      85
#
#      Defense  Sp. Atk  Sp. Def
# 2         83      100      100
# 3        123      122      120
# 50        85      110       90
# 77        65      100       70
# 652       70       85       80

# %%
# want to change before index value and add a new index

new_df = new_df.reset_index()
new_df
# Out:
#    index    #                   Name Type 1  Type 2  Total  Legendary   HP  \
# 0      2    3               Venusaur  Grass  Poison    525      False   80
# 1      3    3  VenusaurMega Venusaur  Grass  Poison    625      False   80
# 2     50   45              Vileplume  Grass  Poison    490      False   75
# 3     77   71             Victreebel  Grass  Poison    490      False   80
# 4    652  591              Amoonguss  Grass  Poison    464      False  114
#
#    Attack  Defense  Sp. Atk  Sp. Def
# 0      82       83      100      100
# 1     100      123      122      120
# 2      80       85      110       90
# 3     105       65      100       70
# 4      85       70       85       80

# %%
df.loc[df['Type 1'].str.contains('Fire|Green')]
# Out:
#        #                       Name Type 1    Type 2  Total  Legendary   HP  \
# 4      4                 Charmander   Fire       NaN    309      False   39
# 5      5                 Charmeleon   Fire       NaN    405      False   58
# 6      6                  Charizard   Fire    Flying    534      False   78
# 7      6  CharizardMega Charizard X   Fire    Dragon    634      False   78
# 8      6  CharizardMega Charizard Y   Fire    Flying    634      False   78
# 42    37                     Vulpix   Fire       NaN    299      False   38
# 43    38                  Ninetales   Fire       NaN    505      False   73
# 63    58                  Growlithe   Fire       NaN    350      False   55
# 64    59                   Arcanine   Fire       NaN    555      False   90
# 83    77                     Ponyta   Fire       NaN    410      False   50
# 84    78                   Rapidash   Fire       NaN    500      False   65
# ...

# %%
 # if we use fire or green f,g in small then 
df.loc[df['Type 1'].str.contains('fire|green')]
# Out:
# Empty DataFrame
# Columns: [#, Name, Type 1, Type 2, Total, Legendary, HP, Attack, Defense, Sp. Atk, Sp. Def]
# Index: []

# %%
# to solve this we need to import function

import re

# %%
df.loc[df['Type 1'].str.contains('fire|green',flags=re.I)]
# Out:
#        #                       Name Type 1    Type 2  Total  Legendary   HP  \
# 4      4                 Charmander   Fire       NaN    309      False   39
# 5      5                 Charmeleon   Fire       NaN    405      False   58
# 6      6                  Charizard   Fire    Flying    534      False   78
# 7      6  CharizardMega Charizard X   Fire    Dragon    634      False   78
# 8      6  CharizardMega Charizard Y   Fire    Flying    634      False   78
# 42    37                     Vulpix   Fire       NaN    299      False   38
# 43    38                  Ninetales   Fire       NaN    505      False   73
# 63    58                  Growlithe   Fire       NaN    350      False   55
# 64    59                   Arcanine   Fire       NaN    555      False   90
# 83    77                     Ponyta   Fire       NaN    410      False   50
# 84    78                   Rapidash   Fire       NaN    500      False   65
# ...

# %%
# pi in name (small or capital cz we use regular expression - flags=re.I )

df.loc[df['Name'].str.contains('pi[a-z]*',flags=re.I)]
# Out:
#        #                     Name    Type 1    Type 2  Total  Legendary   HP  \
# 13    10                 Caterpie       Bug       NaN    195      False   45
# 20    16                   Pidgey    Normal    Flying    251      False   40
# 21    17                Pidgeotto    Normal    Flying    349      False   63
# 22    18                  Pidgeot    Normal    Flying    479      False   83
# 23    18      PidgeotMega Pidgeot    Normal    Flying    579      False   83
# 30    25                  Pikachu  Electric       NaN    320      False   35
# 42    37                   Vulpix      Fire       NaN    299      False   38
# 76    70               Weepinbell     Grass    Poison    390      False   65
# 84    78                 Rapidash      Fire       NaN    500      False   65
# 136  127                   Pinsir       Bug       NaN    500      False   65
# 137  127        PinsirMega Pinsir       Bug    Flying    600      False   65
# ...

# %% [markdown]
# ## Replace

# %%
df.loc[df['Type 1']=='Fire','Type 1'] = 'Flamer'

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total  Legendary  HP  \
# 0      1              Bulbasaur    Grass  Poison    318      False  45
# 1      2                Ivysaur    Grass  Poison    405      False  60
# 2      3               Venusaur    Grass  Poison    525      False  80
# 3      3  VenusaurMega Venusaur    Grass  Poison    625      False  80
# 4      4             Charmander   Flamer     NaN    309      False  39
# ..   ...                    ...      ...     ...    ...        ...  ..
# 795  719                Diancie     Rock   Fairy    600       True  50
# 796  719    DiancieMega Diancie     Rock   Fairy    700       True  50
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600       True  80
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680       True  80
# 799  721              Volcanion   Flamer   Water    600       True  80
#
#      Attack  Defense  Sp. Atk  Sp. Def
# 0        49       49       65       65
# ...

# %%
df.loc[df['Type 1'] == 'Grass','HP']='50'

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total  Legendary  HP  \
# 0      1              Bulbasaur    Grass  Poison    318      False  50
# 1      2                Ivysaur    Grass  Poison    405      False  50
# 2      3               Venusaur    Grass  Poison    525      False  50
# 3      3  VenusaurMega Venusaur    Grass  Poison    625      False  50
# 4      4             Charmander   Flamer     NaN    309      False  39
# ..   ...                    ...      ...     ...    ...        ...  ..
# 795  719                Diancie     Rock   Fairy    600       True  50
# 796  719    DiancieMega Diancie     Rock   Fairy    700       True  50
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600       True  80
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680       True  80
# 799  721              Volcanion   Flamer   Water    600       True  80
#
#      Attack  Defense  Sp. Atk  Sp. Def
# 0        49       49       65       65
# ...

# %%
df.loc[df['Total'] > 500 , ['HP','Attack']] = 0

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total  Legendary  HP  \
# 0      1              Bulbasaur    Grass  Poison    318      False  50
# 1      2                Ivysaur    Grass  Poison    405      False  50
# 2      3               Venusaur    Grass  Poison    525      False   0
# 3      3  VenusaurMega Venusaur    Grass  Poison    625      False   0
# 4      4             Charmander   Flamer     NaN    309      False  39
# ..   ...                    ...      ...     ...    ...        ...  ..
# 795  719                Diancie     Rock   Fairy    600       True   0
# 796  719    DiancieMega Diancie     Rock   Fairy    700       True   0
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600       True   0
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680       True   0
# 799  721              Volcanion   Flamer   Water    600       True   0
#
#      Attack  Defense  Sp. Atk  Sp. Def
# 0        49       49       65       65
# ...

# %%
df.loc[df['Total'] > 500 , ['HP','Attack']] = [1,10]
df
# Out:
#        #                   Name   Type 1  Type 2  Total  Legendary  HP  \
# 0      1              Bulbasaur    Grass  Poison    318      False  50
# 1      2                Ivysaur    Grass  Poison    405      False  50
# 2      3               Venusaur    Grass  Poison    525      False   1
# 3      3  VenusaurMega Venusaur    Grass  Poison    625      False   1
# 4      4             Charmander   Flamer     NaN    309      False  39
# ..   ...                    ...      ...     ...    ...        ...  ..
# 795  719                Diancie     Rock   Fairy    600       True   1
# 796  719    DiancieMega Diancie     Rock   Fairy    700       True   1
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600       True   1
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680       True   1
# 799  721              Volcanion   Flamer   Water    600       True   1
#
#      Attack  Defense  Sp. Atk  Sp. Def
# 0        49       49       65       65
# ...

# %% [markdown]
# ## Group by

# %%
df.groupby(['Type 1']).mean(numeric_only=True)
# Out:
#                    #       Total         HP      Attack     Defense  \
# Type 1
# Bug       334.492754  378.927536  56.884058   70.971014   70.724638
# Dark      461.354839  445.741935  66.806452   88.387097   70.225806
# Dragon    474.375000  550.531250  83.312500  112.125000   86.375000
# Electric  363.500000  443.409091  59.795455   69.090909   66.295455
# Fairy     449.529412  413.176471  74.117647   61.529412   65.705882
# Fighting  363.851852  416.444444  69.851852   96.777778   65.925926
# Fire      327.403846  458.076923  69.903846   84.769231   67.769231
# Flying    677.750000  485.000000  70.750000   78.750000   66.250000
# Ghost     486.500000  439.562500  64.437500   73.781250   81.187500
# Grass     344.871429  421.142857  67.271429   73.214286   70.800000
# Ground    356.281250  437.500000  73.781250   95.750000   84.843750
# Ice       423.541667  433.458333  72.000000   72.750000   71.416667
# Normal    319.173469  401.683673  77.275510   73.469388   59.846939
# ...

# %%
df.groupby(['Type 1']).mean(numeric_only=True).sort_values("Defense",ascending=True)
# Out:
#                    #       Total         HP      Attack     Defense  \
# Type 1
# Normal    319.173469  401.683673  77.275510   73.469388   59.846939
# Fairy     449.529412  413.176471  74.117647   61.529412   65.705882
# Fighting  363.851852  416.444444  69.851852   96.777778   65.925926
# Flying    677.750000  485.000000  70.750000   78.750000   66.250000
# Electric  363.500000  443.409091  59.795455   69.090909   66.295455
# Psychic   380.807018  475.947368  70.631579   71.456140   67.684211
# Fire      327.403846  458.076923  69.903846   84.769231   67.769231
# Poison    251.785714  399.142857  67.250000   74.678571   68.821429
# Dark      461.354839  445.741935  66.806452   88.387097   70.225806
# Bug       334.492754  378.927536  56.884058   70.971014   70.724638
# Grass     344.871429  421.142857  67.271429   73.214286   70.800000
# Ice       423.541667  433.458333  72.000000   72.750000   71.416667
# Water     303.089286  430.455357  72.062500   74.151786   72.946429
# ...

# %%
df.groupby(['Type 1']).sum(numeric_only=True)
# Out:
#               #  Total    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Bug       23080  26146  3925    4897     4880     3717     4471   4256
# Dark      14302  13818  2071    2740     2177     2314     2155   2361
# Dragon    15180  17617  2666    3588     2764     3099     2843   2657
# Electric  15994  19510  2631    3040     2917     3961     3243   3718
# Fairy      7642   7024  1260    1046     1117     1335     1440    826
# Fighting   9824  11244  1886    2613     1780     1434     1747   1784
# Fire      17025  23820  3635    4408     3524     4627     3755   3871
# Flying     2711   1940   283     315      265      377      290    410
# Ghost     15568  14066  2062    2361     2598     2539     2447   2059
# Grass     24141  29480  4709    5125     4956     5425     4930   4335
# Ground    11401  14000  2361    3064     2715     1807     2008   2045
# Ice       10165  10403  1728    1746     1714     1861     1831   1523
# ...

# %%
df.groupby(['Type 1']).count()
# Out:
#             #  Name  Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Type 1
# Bug        69    69      52     69   69      69       69       69       69
# Dark       31    31      21     31   31      31       31       31       31
# Dragon     32    32      21     32   32      32       32       32       32
# Electric   44    44      17     44   44      44       44       44       44
# Fairy      17    17       2     17   17      17       17       17       17
# Fighting   27    27       7     27   27      27       27       27       27
# Fire       52    52      24     52   52      52       52       52       52
# Flying      4     4       2      4    4       4        4        4        4
# Ghost      32    32      22     32   32      32       32       32       32
# Grass      70    70      37     70   70      70       70       70       70
# Ground     32    32      19     32   32      32       32       32       32
# ...

# %%
df.groupby(['Type 1','Type 2']).count()
# Out:
#                   #  Name  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Type 1 Type 2
# Bug    Electric   2     2      2   2       2        2        2        2
#        Fighting   2     2      2   2       2        2        2        2
#        Fire       2     2      2   2       2        2        2        2
#        Flying    14    14     14  14      14       14       14       14
#        Ghost      1     1      1   1       1        1        1        1
# ...              ..   ...    ...  ..     ...      ...      ...      ...
# Water  Ice        3     3      3   3       3        3        3        3
#        Poison     3     3      3   3       3        3        3        3
#        Psychic    5     5      5   5       5        5        5        5
#        Rock       4     4      4   4       4        4        4        4
#        Steel      1     1      1   1       1        1        1        1
#
#                  Speed  Generation  Legendary
# Type 1 Type 2
# ...

# %%
for df_new in pd.read_csv('midified_pokemon.csv',chunksize=5):
    print("Chank df")
    print(df_new)
# Out:
# Chank df
#    Unnamed: 0                    abilities  against_bug  against_dark  \
# 0           0  ['Overgrow', 'Chlorophyll']          1.0           1.0
# 1           1  ['Overgrow', 'Chlorophyll']          1.0           1.0
# 2           2  ['Overgrow', 'Chlorophyll']          1.0           1.0
# 3           3     ['Blaze', 'Solar Power']          0.5           1.0
# 4           4     ['Blaze', 'Solar Power']          0.5           1.0
#
#    against_dragon  against_electric  is_legendary  against_fairy  \
# 0             1.0               0.5             0            0.5
# 1             1.0               0.5             0            0.5
# 2             1.0               0.5             0            0.5
# 3             1.0               1.0             0            0.5
# 4             1.0               1.0             0            0.5
#
#    against_fight  against_fire  against_flying  against_ghost
# 0            0.5           2.0             2.0            1.0
# ...
